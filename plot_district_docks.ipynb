# %%
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bikes_df = pd.read_csv('datasets/current_bluebikes_stations.csv', header=1)
bikes_df.head()
# Out:
#    Number                                 Name   Latitude  Longitude  \
# 0  K32015                       1200 Beacon St  42.344149 -71.114674
# 1  W32006                       160 Arsenal St  42.364664 -71.175694
# 2  A32019                     175 N Harvard St  42.364475 -71.128408
# 3  S32035                        191 Beacon St  42.380323 -71.108786
# 4  C32094  2 Hummingbird Lane at Olmsted Green  42.288870 -71.095003
#
#      District Public  Total docks
# 0   Brookline    Yes           15
# 1   Watertown    Yes           11
# 2      Boston    Yes           17
# 3  Somerville    Yes           19
# 4      Boston    Yes           17

# %%
# convert variables to string dtype
feat = ['Name', 'District']

for feature in feat:
    # case insensitive search - set to lowercase
    #bikes_df[feature] = bikes_df[feature].apply(str.lower).str.strip()
    # apply string data type
    bikes_df[feature] = bikes_df[feature].astype('string')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming bikes_df is your DataFrame

# Set the size of the figure
plt.figure(figsize=(10, 6))  # Adjust the values as needed

# Create the bar plot with all bars as blue
sns.barplot(x='District', y='Total docks', data=bikes_df, errorbar=('ci', 0), color='steelblue')

# Add labels and title
plt.xlabel('District name')
plt.ylabel('Number of bike station docks')
plt.title('Total number of docks in each district for blue bike stations')

# Rotate x-axis labels
plt.xticks(rotation="vertical")

# Display the plot
plt.show()

plt.savefig('district_docks.png')
